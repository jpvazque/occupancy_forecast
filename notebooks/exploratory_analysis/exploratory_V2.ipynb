# %% [markdown]
# # Imports

# %%
# %run ../imports.py

# %%
df=pd.read_excel('../../BDForecasting_V2/AON_1B.xlsx')
df.head()
# Out:
#                      name  occupancy_count        day
# 0  Am Fin. Transformation                0 2020-08-31
# 1        Americas Finance                0 2020-08-31
# 2         Capital Markets                2 2020-08-31
# 3                      CS                0 2020-08-31
# 4           CS Finance-43                0 2020-08-31

# %%
df1=pd.read_excel('./BDForecasting_V2/AON_1B.xlsx')
# df1.drop(["name"], axis = 1, inplace = True)
df1.head()
# Out:
#                      name  occupancy_count        day
# 0  Am Fin. Transformation                0 2020-08-31
# 1        Americas Finance                0 2020-08-31
# 2         Capital Markets                2 2020-08-31
# 3                      CS                0 2020-08-31
# 4           CS Finance-43                0 2020-08-31

# %%
df2=pd.read_excel('./BDForecasting_V2/boa.xlsx')
df2.head()
# Out:
#                         name  2019-12-02 00:00:00  2019-12-03 00:00:00  \
# 0     S&C-PAD: REExecSvcs-PU                    8                   10
# 1  S&C-IHA: CTTreasBusTec-PU                    0                    0
# 2   S&C-IJM: CTGblLiqMgmt-PR                   34                   37
# 3  S&C-IHA: CTTreasBusTec-PU                    3                    3
# 4   S&C-IFZ: CTTreasFinIn-PU                    1                    1
#
#    2019-12-04 00:00:00  2019-12-05 00:00:00  2019-12-09 00:00:00  \
# 0                    9                    8                    8
# 1                    0                    0                    1
# 2                   36                   38                   35
# 3                    3                    3                    3
# 4                    1                    1                    1
#
#    2019-12-10 00:00:00  2019-12-11 00:00:00  2019-12-12 00:00:00  \
# 0                    8                    9                   10
# 1                    1                    1                    1
# 2                   38                   37                   36
# 3                    1                    2                    3
# 4                    1                    1                    1
#
#    2019-12-16 00:00:00  ...  2020-02-11 00:00:00  2020-02-12 00:00:00  \
# 0                    8  ...                    8                    8
# 1                    1  ...                    0                    0
# 2                   35  ...                   38                   38
# 3                    3  ...                    4                    4
# 4                    1  ...                    2                    2
#
#    2020-02-13 00:00:00  2020-02-18 00:00:00  2020-02-19 00:00:00  \
# 0                    9                   11                    9
# 1                    0                    0                    0
# 2                   39                   38                   37
# 3                    4                    4                    4
# 4                    2                    2                    2
#
#    2020-02-20 00:00:00  2020-02-24 00:00:00  2020-02-25 00:00:00  \
# 0                    5                    7                    7
# 1                    0                    0                    0
# 2                   38                   39                   40
# 3                    4                    3                    3
# 4                    2                    2                    2
#
#    2020-02-26 00:00:00  2020-02-27 00:00:00
# 0                    8                    6
# 1                    0                    0
# 2                   39                   40
# 3                    4                    4
# 4                    2                    2
#
# [5 rows x 44 columns]

# %% [markdown]
# # Base 3

# %%
# df3=pd.read_csv('/content/drive/MyDrive/PYW EDA /bases/BaseVertical.csv')
df3=pd.read_csv('./BDForecasting_V2/BaseVertical_V2.csv')
df3.head()
# Out:
#    Unnamed: 0                    SITE                DATES  OCCUPANCY_COUNT
# 0           0  S&C-PAD: REExecSvcs-PU  2018-01-01 01:00:00                8
# 1           1  S&C-PAD: REExecSvcs-PU  2018-01-01 02:00:00               10
# 2           2  S&C-PAD: REExecSvcs-PU  2018-01-01 03:00:00                5
# 3           3  S&C-PAD: REExecSvcs-PU  2018-01-01 04:00:00                2
# 4           4  S&C-PAD: REExecSvcs-PU  2018-01-01 05:00:00                3

# %% [markdown]
# This line converts the dataset from horizontal to vertical

# %%
df2 = df2.set_index('name').stack().reset_index().rename(columns={'level_1': 'day', 0: 'occupancy_count'})

# %%
df2.head()
# Out:
#                      name        day  occupancy_count
# 0  S&C-PAD: REExecSvcs-PU 2019-12-02                8
# 1  S&C-PAD: REExecSvcs-PU 2019-12-03               10
# 2  S&C-PAD: REExecSvcs-PU 2019-12-04                9
# 3  S&C-PAD: REExecSvcs-PU 2019-12-05                8
# 4  S&C-PAD: REExecSvcs-PU 2019-12-09                8

# %%
df1=df1.groupby(['day']).sum()
df1.head()
# Out:
#             occupancy_count
# day
# 2020-08-31               47
# 2020-09-01               63
# 2020-09-02               64
# 2020-09-03               54
# 2020-09-04               22

# %%
df2.groupby(['day']).sum()
# Out:
#             occupancy_count
# day
# 2019-12-02             2072
# 2019-12-03             2174
# 2019-12-04             2214
# 2019-12-05             2152
# 2019-12-09             2145
# 2019-12-10             2201
# 2019-12-11             2208
# 2019-12-12             2135
# 2019-12-16             2031
# 2019-12-17             2080
# 2019-12-18             2042
# 2019-12-19             1856
# 2020-01-02             1429
# 2020-01-06             2271
# 2020-01-07             2288
# 2020-01-08             2221
# 2020-01-09             2307
# 2020-01-13             2228
# 2020-01-14             2320
# 2020-01-15             2319
# 2020-01-16             2281
# 2020-01-21             2257
# 2020-01-22             2298
# 2020-01-23             2259
# 2020-01-27             2291
# 2020-01-28             2353
# 2020-01-29             2351
# 2020-01-30             2312
# 2020-02-03             2231
# 2020-02-04             2292
# 2020-02-05             2272
# 2020-02-06             2154
# 2020-02-10             2313
# 2020-02-11             2330
# 2020-02-12             2361
# 2020-02-13             2293
# 2020-02-18             2300
# 2020-02-19             2297
# 2020-02-20             2072
# 2020-02-24             2342
# 2020-02-25             2377
# 2020-02-26             2358
# 2020-02-27             2256

# %% [markdown]
# # redindexar

# %%
df1.index = df1.day
df1.drop(["day"], axis = 1, inplace = True) 
df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-2ada0e931a0c> in <module>
# ----> 1 df1.index = df1.day
#       2 df1.drop(["day"], axis = 1, inplace = True)
#       3 df1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'day'

# %%
df2.index = df2.day
df2.drop(["day"], axis = 1, inplace = True) 
df2

# %%
df2=df2.groupby(['day']).sum()
df2.head()
# Out:
#             occupancy_count
# day
# 2019-12-02             2072
# 2019-12-03             2174
# 2019-12-04             2214
# 2019-12-05             2152
# 2019-12-09             2145

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2697256 entries, 0 to 2697255
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Unnamed: 0       int64
#  1   SITE             object
#  2   DATES            object
#  3   OCCUPANCY_COUNT  int64
# dtypes: int64(2), object(2)
# memory usage: 82.3+ MB

# %%
df3.index = df3.DATES
df3.drop(["DATES"], axis = 1, inplace = True) 
df3
# Out:
#                      Unnamed: 0                       SITE  OCCUPANCY_COUNT
# DATES
# 2018-01-01 01:00:00           0     S&C-PAD: REExecSvcs-PU                8
# 2018-01-01 02:00:00           1     S&C-PAD: REExecSvcs-PU               10
# 2018-01-01 03:00:00           2     S&C-PAD: REExecSvcs-PU                5
# 2018-01-01 04:00:00           3     S&C-PAD: REExecSvcs-PU                2
# 2018-01-01 05:00:00           4     S&C-PAD: REExecSvcs-PU                3
# ...                         ...                        ...              ...
# 2020-12-31 19:00:00       25203  S&C-ABL: LegCorpSec-PR-EX                3
# 2020-12-31 20:00:00       25204  S&C-ABL: LegCorpSec-PR-EX                4
# 2020-12-31 21:00:00       25205  S&C-ABL: LegCorpSec-PR-EX                5
# 2020-12-31 22:00:00       25206  S&C-ABL: LegCorpSec-PR-EX                3
# 2020-12-31 23:00:00       25207  S&C-ABL: LegCorpSec-PR-EX                9
#
# [2697256 rows x 3 columns]

# %%
df3=df3.groupby(['DATES']).sum()
df3
# Out:
#                      Unnamed: 0  OCCUPANCY_COUNT
# DATES
# 2018-01-01 01:00:00           0              795
# 2018-01-01 02:00:00         107              822
# 2018-01-01 03:00:00         214              730
# 2018-01-01 04:00:00         321              507
# 2018-01-01 05:00:00         428              488
# ...                         ...              ...
# 2020-12-31 19:00:00     2696721              657
# 2020-12-31 20:00:00     2696828              616
# 2020-12-31 21:00:00     2696935              664
# 2020-12-31 22:00:00     2697042              541
# 2020-12-31 23:00:00     2697149              528
#
# [25208 rows x 2 columns]

# %% [markdown]
# # union of the two bases

# %%
df=df2.append(df1,sort=True)
df.head()
# Out:
#             occupancy_count
# day
# 2019-12-02             2072
# 2019-12-03             2174
# 2019-12-04             2214
# 2019-12-05             2152
# 2019-12-09             2145

# %% [markdown]
# # Initial exploration
#
# Get empty values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 118 entries, 2019-12-02 to 2020-12-11
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   occupancy_count  118 non-null    int64
# dtypes: int64(1)
# memory usage: 1.8 KB

# %%
df.isna().sum()
# Out:
# occupancy_count    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# occupancy_count    0
# dtype: int64

# %% [markdown]
# # Numeric variables

# %%
# nombre de columnas numéricas
numeric_variables = df._get_numeric_data().columns.values
numeric_variables
# Out:
# array(['occupancy_count'], dtype=object)

# %%
numeric_variables.shape[0]
# Out:
# 1

# %%
sns.set(style = 'white')
plt.rc('font', family='serif')


c_background = '#FFFFFF'

colours = ['#8D7BBC', '#60A561', '#EDAE49', '#D1495B', '#1E3231', '#00798C', '#30638E', '#003D5B' ]

#histograma de distribuciones
sns.set(style = 'white', font_scale=1.3)
plt.rc('font', family='serif')

df[numeric_variables].hist(bins = 15,
                           color = colours[0],
                           figsize = (10,10),
                           )
plt.show()

# %%
#df[numeric_variables].plot(kind='box', figsize=[16,8])

# %%
df['occupancy_count'].describe()
# Out:
# count     118.000000
# mean      855.084746
# std      1040.869505
# min         0.000000
# 25%        68.250000
# 50%        97.000000
# 75%      2206.250000
# max      2377.000000
# Name: occupancy_count, dtype: float64

# %% [markdown]
# # *Normality*
#  we can identify the outliers

# %%
def normalidad_variable_numerica(col):
    stats.probplot(df[col], plot=plt)
    plt.xlabel('Diagrama de Probabilidad(normal) de la variable {}'.format(col))
    plt.show()

# %%
normalidad_variable_numerica('occupancy_count')

# %%
for num_col in numeric_variables:
    _, pval = stats.normaltest(df[num_col])
    if(pval < 0.05):
        print("Columna {} no sigue una distribución normal".format(num_col))
# Out:
# Columna occupancy_count no sigue una distribución normal

# %% [markdown]
# # Category variables

# %%
all_variables = df.columns.values
categorical_variables = np.setdiff1d( all_variables, numeric_variables )
categorical_variables
# Out:
# array(['day', 'name'], dtype=object)

# %%
for i in df[categorical_variables].columns.values:
    print("Valores de ", i,'\n')
    print(df[i].value_counts())
    print('\n\n')
# Out:
# Valores de  day
#
# 2020-12-11    57
# 2020-08-31    57
# 2020-10-27    57
# 2020-10-05    57
# 2020-12-01    57
#               ..
# 2020-11-03    57
# 2020-10-12    57
# 2020-12-08    57
# 2020-11-16    57
# 2020-09-01    57
# Name: day, Length: 75, dtype: int64
#
#
#
# Valores de  name
#
# Markets Global Hotels       75
# Property Mgmt Office-44     75
# Markets Marketing           75
# FP&A                        75
# Markets Property Mgmt       75
# IT/Telecom                  75
# Global Tax                  75
# Markets Research            75
# Legal                       75
# PDS-44                      75
# Markets HR                  75
# TDIM                        75
# HR                          75
# Global HR                   75
# IT/Network Services         75
# IT                          75
# CS                          75
# IT/Tech Fulfilment          75
# Product                     75
# Hotels/Cap Markets          75
# Am Fin. Transformation      75
# National Retail             75
# IFM P&G                     75
# IT/Enhanced Support         75
# Markets PDS                 75
# Markets-45                  75
# Markets VAS                 75
# IT/Deskside Support         75
# Property Mgmt Office        75
# Markets Sol Finance         75
# IT/IBM                      75
# IPS                         75
# PI / USPS                   75
# Americas Finance            75
# Payroll                     75
# Markets Operations          75
# Markets Sales Enablement    75
# Capital Markets             75
# Marketing                   75
# MISC.                       75
# Markets-46                  75
# Property Mgmt Office-46     75
# CS Finance-44               75
# Mergers & Acquisitions      75
# Markets Agency Leasing      75
# Markets Sol Investors       75
# PDS-45                      75
# IFM                         75
# Visitor                     75
# Markets Accounting          75
# OFS                         75
# Global Finance              75
# CS Finance-43               75
# Risk                        75
# Property Mgmt Industrial    75
# Markets Retail              75
# Research                    75
# Name: name, dtype: int64

# %%
def distribucion_variable_categorica(col):
    df[col].value_counts(ascending=True,normalize=True).tail(20).plot.barh()
    plt.show()

# %%
# distribucion_variable_categorica('name')

# %% [markdown]
# # Variations by one unit time (day)

# %%
desplazado = df['occupancy_count'].shift(1)
desplazado[:5]
# Out:
# 0    NaN
# 1    0.0
# 2    0.0
# 3    2.0
# 4    0.0
# Name: occupancy_count, dtype: float64

# %%
df['var_diaria']=df['occupancy_count'].pct_change()
df['var_diaria'][:5]
# Out:
# 0    NaN
# 1    NaN
# 2    inf
# 3   -1.0
# 4    NaN
# Name: var_diaria, dtype: float64

# %% [markdown]
# ## Applying the Hodrick-Prescott filter to separate in trend and
# ## cyclic component.

# %%
# Aplicando el filtro Hodrick-Prescott para separar en tendencia y 
# componente ciclico.
oc_ciclo, oc_tend = sm.tsa.filters.hpfilter(df['occupancy_count'])
df['oc_tend'] = oc_tend

# %%
# # calculando rendimiento acumulado diario
# rendimiento_diario=(1 + df['occupancy_count'].pct_change()).cumprod()
# df['rend_diario'] = rendimiento_diario
# df['rend_diario']

# %% [markdown]
# # Zeros,nan,null after calculations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4275 entries, 0 to 4274
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             4275 non-null   object
#  1   occupancy_count  4275 non-null   int64
#  2   day              4275 non-null   datetime64[ns]
#  3   var_diaria       2653 non-null   float64
#  4   oc_tend          4275 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 167.1+ KB

# %%
df.var_diaria[df.var_diaria==0].count()
# Out:
# 192

# %%
df.oc_tend[df.oc_tend==0].count()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# name                  0
# occupancy_count       0
# day                   0
# var_diaria         1622
# oc_tend               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name                  0
# occupancy_count       0
# day                   0
# var_diaria         1622
# oc_tend               0
# dtype: int64

# %% [markdown]
# # Visualizating

# %% [markdown]
# ## Define date

# %%
df.occupancy_count[df.occupancy_count<10]['2020-03':'2020-09'].count()
# Out:
# 1

# %%
date='2020'
# date=['2020-03':'2020-09']

# %% [markdown]
# ## Graphics of  occupancy_count BASE 1 Y 2

# %%
# graficando occupancy_count
plot = df['occupancy_count'].plot(figsize=(10, 8))
plt.show()

# %% [markdown]
# ## Graphics of  occupancy_count BASE 1

# %%
# graficando occupancy_count 
plot = df1['occupancy_count'].plot(figsize=(10, 8))
plt.show()

# %% [markdown]
# ## Graphics of  occupancy_count BASE 2

# %%
# graficando occupancy_count
plot = df2['occupancy_count'].plot(figsize=(10, 8))
plt.show()

# %%
df['occupancy_count']['2020-05':'2020-07']
# Out:
# Series([], Name: occupancy_count, dtype: int64)

# %%
plot2 = df['occupancy_count']['2020-05':'2020-07'].plot(figsize=(10, 8))
plt.show()

# %%
plot = df['occupancy_count']['2020-04':'2020-09'].plot(figsize=(10, 8))
plt.show()

# %%
# graficando la variacion del precio real con la tendencia.
df[['occupancy_count','oc_tend']].plot(figsize=(10, 8), fontsize=12)
# df[date][['occupancy_count','oc_tend']].plot(figsize=(10, 8), fontsize=12);
# wft[['Adj Close', 'tend']].plot(figsize=(10, 8), fontsize=12);
legend = plt.legend()
legend.prop.set_size(14);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-c2814d5ee1f7> in <module>
#       1 # graficando la variacion del precio real con la tendencia.
# ----> 2 df[['occupancy_count','oc_tend']].plot(figsize=(10, 8), fontsize=12)
#       3 # df[date][['occupancy_count','oc_tend']].plot(figsize=(10, 8), fontsize=12);
#       4 # wft[['Adj Close', 'tend']].plot(figsize=(10, 8), fontsize=12);
#       5 legend = plt.legend()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['oc_tend'] not in index"

# %%
df['var_diaria'].plot(figsize=(10, 8))

# %%
df3.head(25)

# %% [markdown]
# ## Base 3 per day

# %%
plot_monday = df3.OCCUPANCY_COUNT['2018-01-01 01:00:00':'2018-01-02 01:00:00'].plot(figsize=(20, 8))
plt.title('Monday 2018-01-01')
plt.show()

# %%
plot_tuesday = df3.OCCUPANCY_COUNT['2018-01-02 01:00:00':'2018-01-03 01:00:00'].plot(figsize=(20, 8))
plt.title('Tuesday 2018-01-02')
plt.show()

# %%
plot_wednesday = df3.OCCUPANCY_COUNT['2018-01-03 01:00:00':'2018-01-04 01:00:00'].plot(figsize=(20, 8))
plt.title('Wedneaday 2018-01-03')
plt.show()

# %%
plot_thursday = df3.OCCUPANCY_COUNT['2018-01-04 01:00:00':'2018-01-05 01:00:00'].plot(figsize=(20, 8))
plt.title('Thursday 2018-01-04')
plt.show()

# %%
plot_friday = df3.OCCUPANCY_COUNT['2018-01-05 01:00:00':'2018-01-06 01:00:00'].plot(figsize=(20, 8))
plt.title('Friday 2018-01-05')
plt.show()

# %%
plot_saturday = df3.OCCUPANCY_COUNT['2018-01-06 01:00:00':'2018-01-07 01:00:00'].plot(figsize=(20, 8))
plt.title('Saturday 2018-01-06')
plt.show()

# %%
plot_sunday = df3.OCCUPANCY_COUNT['2018-01-07 01:00:00':'2018-01-08 01:00:00'].plot(figsize=(20, 8))
plt.title('Sunday 2018-01-07')
plt.show()

# %% [markdown]
# ## Base 3 per week

# %%
plot_week = df3.OCCUPANCY_COUNT['2018-01-01':'2018-01-08'].plot(figsize=(20, 8), fontsize=10)
plt.title('Week from 2018-01-01 to 2018-01-07')
plt.show()

# %% [markdown]
# ## Base 3 per month

# %%
plot_week = df3.OCCUPANCY_COUNT['2018-01-01':'2018-03-01'].plot(figsize=(20, 8), fontsize=10)
plt.title('January 2018')
plt.show()

# %% [markdown]
# # Base 3 per year

# %%
plot31 = df3.OCCUPANCY_COUNT['2018-01':'2018-02'].plot(figsize=(20, 8))
plt.show()

# %%
plot32 = df3.OCCUPANCY_COUNT['2019-01':'2020-01'].plot(figsize=(20, 8))
plt.show()

# %%
plot33 = df3.OCCUPANCY_COUNT['2020-01':'2020-12'].plot(figsize=(20, 8))
plt.show()

# %% [markdown]
# ## Database3 decomposition by year
#
# Time series decomposition every 30 days per semester

# %%
# Descomposición de serie de tiempo cada 30 dias por semestre 
from pylab import rcParams
rcParams['figure.figsize'] = 20, 9
descomposicion = sm.tsa.seasonal_decompose(df3.OCCUPANCY_COUNT['2018-01':'2018-06'],model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   after removing the cwd from sys.path.

# %%
rcParams['figure.figsize'] = 20, 9
descomposicion = sm.tsa.seasonal_decompose(df3.OCCUPANCY_COUNT['2018-06':'2018-12'],model='additive', freq=30)  
fig = descomposicion.plot()

# %%
rcParams['figure.figsize'] = 20, 9
descomposicion = sm.tsa.seasonal_decompose(df3.OCCUPANCY_COUNT['2019-01':'2019-06'],model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
rcParams['figure.figsize'] = 20, 9
descomposicion = sm.tsa.seasonal_decompose(df3.OCCUPANCY_COUNT['2019-06':'2019-12'],model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
rcParams['figure.figsize'] = 20, 9
descomposicion = sm.tsa.seasonal_decompose(df3.OCCUPANCY_COUNT['2020-01':'2020-06'],model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %%
rcParams['figure.figsize'] = 20, 9
descomposicion = sm.tsa.seasonal_decompose(df3.OCCUPANCY_COUNT['2020-06':'2020-12'],model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ## Calculating moving averages every 5 days

# %%
# Calculando promedios móviles cada 5 días
df_ma=df['occupancy_count'].rolling(5).mean()
df['prod_mov'] = df_ma
plot = df[date][['occupancy_count', 'prod_mov']].plot(figsize=(10, 8), fontsize=12)

# %% [markdown]
# ## Time series (1 AND 2) decomposition every 30 days

# %%
# Descomposición de serie de tiempo cada 30 dias
from pylab import rcParams
rcParams['figure.figsize'] = 11, 9

descomposicion = sm.tsa.seasonal_decompose(df['occupancy_count'],
                                                  model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ## Descomposición de serie 1

# %%
# Descomposición de serie de tiempo cada 30 dias
from pylab import rcParams
rcParams['figure.figsize'] = 11, 9

descomposicion = sm.tsa.seasonal_decompose(df1['occupancy_count'],
                                                  model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ## Descomposición de serie 2

# %%
# Descomposición de serie de tiempo cada 30 dias
from pylab import rcParams
rcParams['figure.figsize'] = 11, 9

descomposicion = sm.tsa.seasonal_decompose(df2['occupancy_count'],
                                                  model='additive', freq=30)  
fig = descomposicion.plot()
# Out:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\Users\59399\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
